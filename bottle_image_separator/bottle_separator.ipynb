# %%
import cv2 as cv
import os
from ultralytics import YOLO
import numpy as np

# %%
new_ds = '../separated_bottles'
os.makedirs(new_ds, exist_ok=True)
path = '../bottles_imgs'
folders = os.listdir(path)
folders = [folder for folder in folders if not folder.endswith('.DS_Store')]
folders
# Out:
# ['mountaindew', 'pocari', 'coke']

# %%
def detect_Object(frame):
    # print(frame)
    model = YOLO('yolov8n.pt')

    detected_obj = model.predict(frame, conf=0.5, save=False, classes = [39])
    names = model.names

    if len(detected_obj) != 0:
        for obj in detected_obj:
            for deets in obj.boxes.data.tolist():
                xmin, ymin, xmax, ymax = int(deets[0]), int(deets[1]), int(deets[2]), int(deets[3])
                roi = frame[ymin:ymax, xmin:xmax]
                # print(roi)
                # # TODO: CNN Classifier
                # cv.rectangle(frame, (xmin, ymin) , (xmax, ymax), (0,255,0), 2)
                # cv.putText(frame, str(names[deets[5]]), (xmin, ymin - 15), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                if roi is not None:
                    return roi
                else: return None

# %%
for folder in folders:
        folder_path = os.path.join(path, folder)
        images = os.listdir(f'{path}/{folder}')
        new_folder = os.path.join(new_ds, folder)
        os.makedirs(new_folder, exist_ok=True)
        # print(images)
        for image in images:
            image_path = os.path.join(folder_path, image)
            img_array = cv.imread(image_path)
            separated = detect_Object(img_array)
            # print(image_path)#
            
            if separated is not None:
                if separated.any():
                    print(len(separated))
            # cv.imshow('title', img_array)
                    obj_filename = f"{new_folder}/{os.path.basename(image_path)}.jpg"
                    print(separated)
                    cv.imwrite(obj_filename, separated)
# Out:
# 0: 384x640 1 bottle, 145.7ms
# Speed: 3.2ms preprocess, 145.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 366
# [[[147 151 152]
#   [147 151 152]
#   [146 150 151]
#   ...
#   [143 143 143]
#   [143 143 143]
#   [142 142 142]]
#
#  [[145 149 150]
#   [145 149 150]
#   [146 150 151]
#   ...
#   [145 145 145]
#   [145 145 145]
#   [144 144 144]]
#
#  [[147 152 151]
#   [146 151 150]
#   [144 148 149]
#   ...
#   [146 146 146]
#   [146 146 146]
#   [146 146 146]]
#
#  ...
#
#  [[ 92 110 109]
#   [ 90 111 109]
#   [ 88 109 110]
#   ...
#   [ 37  80  77]
#   [ 36  79  76]
#   [ 35  78  75]]
#
#  [[ 92 110 109]
#   [ 90 111 109]
#   [ 87 108 109]
#   ...
#   [ 34  77  74]
#   [ 34  77  74]
#   [ 33  76  73]]
#
#  [[ 92 110 109]
#   [ 91 109 108]
#   [ 89 109 110]
#   ...
#   [ 32  75  72]
#   [ 32  75  72]
#   [ 31  74  71]]]
# 0: 384x640 1 bottle, 144.4ms
# Speed: 4.2ms preprocess, 144.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 356
# [[[163 162 164]
#   [163 162 164]
#   [163 162 164]
#   ...
#   [151 155 156]
#   [151 155 156]
#   [151 155 156]]
#
#  [[163 162 164]
#   [163 162 164]
#   [163 162 164]
#   ...
#   [153 157 158]
#   [153 157 158]
#   [154 158 159]]
#
#  [[164 163 165]
#   [163 162 164]
#   [163 162 164]
#   ...
#   [152 156 157]
#   [152 156 157]
#   [152 156 157]]
#
#  ...
#
#  [[ 97 119 117]
#   [ 99 121 119]
#   [100 122 120]
#   ...
#   [ 54  87  83]
#   [ 56  89  85]
#   [ 57  90  86]]
#
#  [[ 96 118 116]
#   [ 97 119 117]
#   [ 98 120 118]
#   ...
#   [ 55  88  84]
#   [ 56  89  85]
#   [ 56  89  85]]
#
#  [[ 95 117 115]
#   [ 96 118 116]
#   [ 97 119 117]
#   ...
#   [ 58  89  86]
#   [ 58  89  86]
#   [ 58  89  86]]]
# 0: 384x640 (no detections), 128.1ms
# Speed: 2.8ms preprocess, 128.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 135.8ms
# Speed: 2.3ms preprocess, 135.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 137.6ms
# Speed: 2.4ms preprocess, 137.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 319
# [[[179 168 170]
#   [181 173 174]
#   [169 161 162]
#   ...
#   [ 26  31  30]
#   [ 26  31  30]
#   [ 26  31  30]]
#
#  [[180 169 171]
#   [181 173 174]
#   [169 161 162]
#   ...
#   [ 27  32  31]
#   [ 26  31  30]
#   [ 26  31  30]]
#
#  [[180 172 173]
#   [176 168 169]
#   [166 158 159]
#   ...
#   [ 27  32  31]
#   [ 26  31  30]
#   [ 26  31  30]]
#
#  ...
#
#  [[112 124 124]
#   [110 124 123]
#   [110 124 123]
#   ...
#   [124 140 152]
#   [124 140 153]
#   [124 140 153]]
#
#  [[110 122 122]
#   [108 122 121]
#   [108 122 121]
#   ...
#   [124 140 152]
#   [125 141 154]
#   [125 141 154]]
#
#  [[110 122 122]
#   [107 121 120]
#   [107 121 120]
#   ...
#   [124 140 152]
#   [124 140 153]
#   [125 141 154]]]
# 0: 384x640 (no detections), 139.7ms
# Speed: 2.6ms preprocess, 139.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 142.5ms
# Speed: 2.8ms preprocess, 142.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.4ms
# Speed: 9.8ms preprocess, 153.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 128.2ms
# Speed: 2.6ms preprocess, 128.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 134.1ms
# Speed: 4.5ms preprocess, 134.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 366
# [[[ 92  87  86]
#   [ 90  85  84]
#   [ 90  85  84]
#   ...
#   [ 11  19   9]
#   [ 11  19   9]
#   [ 11  19   9]]
#
#  [[ 91  86  85]
#   [ 91  86  85]
#   [ 91  86  85]
#   ...
#   [ 12  20  10]
#   [ 12  20  10]
#   [ 12  20  10]]
#
#  [[ 90  85  84]
#   [ 90  85  84]
#   [ 91  86  85]
#   ...
#   [ 12  20  10]
#   [ 12  20  10]
#   [ 12  20  10]]
#
#  ...
#
#  [[115 131 130]
#   [114 132 131]
#   [112 133 131]
#   ...
#   [125 146 148]
#   [125 145 146]
#   [124 144 145]]
#
#  [[114 130 129]
#   [113 131 130]
#   [111 132 130]
#   ...
#   [126 147 149]
#   [125 145 146]
#   [125 145 146]]
#
#  [[113 129 128]
#   [112 130 129]
#   [111 132 130]
#   ...
#   [127 148 149]
#   [126 146 147]
#   [125 145 146]]]
# 0: 384x640 (no detections), 138.1ms
# Speed: 2.5ms preprocess, 138.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 127.2ms
# Speed: 2.7ms preprocess, 127.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 138.6ms
# Speed: 2.4ms preprocess, 138.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 352
# [[[149 153 154]
#   [151 153 154]
#   [150 152 153]
#   ...
#   [145 149 150]
#   [145 150 149]
#   [145 150 149]]
#
#  [[150 154 155]
#   [150 152 153]
#   [150 152 153]
#   ...
#   [144 148 149]
#   [145 150 149]
#   [145 150 149]]
#
#  [[149 153 154]
#   [150 152 153]
#   [150 152 153]
#   ...
#   [141 145 146]
#   [143 148 147]
#   [142 147 146]]
#
#  ...
#
#  [[ 94 112 111]
#   [ 93 114 112]
#   [ 92 114 112]
#   ...
#   [ 49  80  79]
#   [ 51  81  82]
#   [ 51  81  82]]
#
#  [[ 95 111 110]
#   [ 95 113 112]
#   [ 93 114 112]
#   ...
#   [ 51  82  81]
#   [ 52  82  83]
#   [ 52  82  83]]
#
#  [[ 96 112 111]
#   [ 95 113 112]
#   [ 93 114 112]
#   ...
#   [ 55  83  83]
#   [ 54  82  82]
#   [ 53  81  81]]]
# 0: 384x640 1 bottle, 130.8ms
# Speed: 4.3ms preprocess, 130.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 401
# [[[150 152 160]
#   [151 153 161]
#   [150 153 158]
#   ...
#   [127 135 142]
#   [127 136 140]
#   [126 134 141]]
#
#  [[149 151 159]
#   [151 153 161]
#   [150 153 158]
#   ...
#   [127 136 140]
#   [127 136 140]
#   [127 135 142]]
#
#  [[149 151 159]
#   [150 152 160]
#   [150 153 158]
#   ...
#   [128 137 141]
#   [128 137 141]
#   [125 135 142]]
#
#  ...
#
#  [[100 118 117]
#   [102 120 119]
#   [100 121 119]
#   ...
#   [ 49  82  85]
#   [ 49  82  85]
#   [ 52  83  86]]
#
#  [[101 119 118]
#   [102 120 119]
#   [100 121 119]
#   ...
#   [ 51  84  87]
#   [ 51  84  87]
#   [ 53  84  87]]
#
#  [[102 120 119]
#   [102 120 119]
#   [ 99 120 118]
#   ...
#   [ 54  85  86]
#   [ 54  85  86]
#   [ 56  86  87]]]
# 0: 384x640 1 bottle, 127.5ms
# Speed: 2.6ms preprocess, 127.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 366
# [[[144 148 149]
#   [144 148 149]
#   [144 148 149]
#   ...
#   [134 138 139]
#   [134 138 139]
#   [134 138 139]]
#
#  [[143 147 148]
#   [143 147 148]
#   [143 147 148]
#   ...
#   [136 140 141]
#   [136 140 141]
#   [136 140 141]]
#
#  [[142 146 147]
#   [142 146 147]
#   [142 146 147]
#   ...
#   [138 143 142]
#   [138 143 142]
#   [138 143 142]]
#
#  ...
#
#  [[ 95 109 107]
#   [ 93 110 107]
#   [ 93 110 107]
#   ...
#   [ 36  77  72]
#   [ 35  76  71]
#   [ 35  76  71]]
#
#  [[ 95 109 107]
#   [ 93 110 107]
#   [ 91 110 107]
#   ...
#   [ 35  76  71]
#   [ 34  75  70]
#   [ 33  74  69]]
#
#  [[ 94 108 106]
#   [ 92 109 106]
#   [ 91 110 107]
#   ...
#   [ 33  74  69]
#   [ 33  74  69]
#   [ 33  74  69]]]
# 0: 384x640 1 bottle, 135.4ms
# Speed: 2.9ms preprocess, 135.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 345
# [[[150 152 160]
#   [149 152 157]
#   [148 151 155]
#   ...
#   [138 150 156]
#   [125 136 140]
#   [125 137 139]]
#
#  [[148 150 158]
#   [148 151 156]
#   [146 149 153]
#   ...
#   [132 142 149]
#   [129 138 142]
#   [130 139 142]]
#
#  [[145 147 155]
#   [145 148 153]
#   [144 147 151]
#   ...
#   [125 136 140]
#   [129 138 141]
#   [127 137 137]]
#
#  ...
#
#  [[ 92 110 109]
#   [ 92 111 108]
#   [ 94 111 108]
#   ...
#   [ 44  77  80]
#   [ 42  75  78]
#   [ 42  75  78]]
#
#  [[ 93 111 110]
#   [ 93 112 109]
#   [ 93 112 109]
#   ...
#   [ 47  78  81]
#   [ 44  75  78]
#   [ 45  76  79]]
#
#  [[ 91 109 108]
#   [ 92 111 108]
#   [ 95 114 111]
#   ...
#   [ 47  78  81]
#   [ 47  78  81]
#   [ 47  78  81]]]
# 0: 384x640 1 bottle, 146.1ms
# Speed: 4.4ms preprocess, 146.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 354
# [[[160 162 163]
#   [158 162 163]
#   [158 162 163]
#   ...
#   [152 156 157]
#   [152 156 157]
#   [151 155 156]]
#
#  [[160 162 163]
#   [161 163 164]
#   [161 163 164]
#   ...
#   [153 157 158]
#   [153 157 158]
#   [151 155 156]]
#
#  [[161 163 164]
#   [161 163 164]
#   [161 163 164]
#   ...
#   [152 156 157]
#   [151 155 156]
#   [150 154 155]]
#
#  ...
#
#  [[100 118 117]
#   [ 98 119 117]
#   [ 97 119 117]
#   ...
#   [ 57  88  87]
#   [ 56  87  86]
#   [ 57  85  86]]
#
#  [[100 118 117]
#   [ 98 119 117]
#   [ 98 119 117]
#   ...
#   [ 57  88  87]
#   [ 56  87  86]
#   [ 57  85  86]]
#
#  [[100 118 117]
#   [ 98 119 117]
#   [ 98 119 117]
#   ...
#   [ 60  88  88]
#   [ 60  88  88]
#   [ 60  85  87]]]
# 0: 384x640 (no detections), 180.7ms
# Speed: 2.5ms preprocess, 180.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 140.3ms
# Speed: 3.6ms preprocess, 140.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 448
# [[[ 63  80  93]
#   [ 85 102 123]
#   [ 98 117 144]
#   ...
#   [122 120 120]
#   [123 121 121]
#   [124 122 122]]
#
#  [[ 56  74  85]
#   [ 78  95 114]
#   [ 95 112 138]
#   ...
#   [122 120 120]
#   [123 121 121]
#   [124 122 122]]
#
#  [[ 50  68  79]
#   [ 71  89 106]
#   [ 89 107 130]
#   ...
#   [121 121 121]
#   [122 122 122]
#   [122 122 122]]
#
#  ...
#
#  [[ 62  75  73]
#   [ 63  76  74]
#   [ 63  76  74]
#   ...
#   [ 70  84  78]
#   [ 69  83  77]
#   [ 67  81  75]]
#
#  [[ 61  74  72]
#   [ 61  74  72]
#   [ 62  75  73]
#   ...
#   [ 74  88  82]
#   [ 70  84  78]
#   [ 67  81  75]]
#
#  [[ 61  74  72]
#   [ 60  73  71]
#   [ 61  74  72]
#   ...
#   [ 74  88  82]
#   [ 72  86  80]
#   [ 70  84  78]]]
# 0: 384x640 (no detections), 187.4ms
# Speed: 4.2ms preprocess, 187.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.1ms
# Speed: 3.2ms preprocess, 148.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 210.6ms
# Speed: 3.7ms preprocess, 210.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.3ms
# Speed: 5.3ms preprocess, 156.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.1ms
# Speed: 3.5ms preprocess, 163.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 126.5ms
# Speed: 4.4ms preprocess, 126.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.4ms
# Speed: 3.4ms preprocess, 161.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.2ms
# Speed: 3.5ms preprocess, 133.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 146.1ms
# Speed: 2.8ms preprocess, 146.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.3ms
# Speed: 3.3ms preprocess, 131.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 128.1ms
# Speed: 2.8ms preprocess, 128.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 354
# [[[162 161 163]
#   [162 161 163]
#   [163 162 164]
#   ...
#   [152 156 157]
#   [152 156 157]
#   [152 156 157]]
#
#  [[163 162 164]
#   [163 162 164]
#   [162 161 163]
#   ...
#   [153 157 158]
#   [153 157 158]
#   [153 157 158]]
#
#  [[165 164 166]
#   [164 163 165]
#   [163 162 164]
#   ...
#   [151 155 156]
#   [151 155 156]
#   [151 155 156]]
#
#  ...
#
#  [[ 98 123 119]
#   [ 98 123 119]
#   [ 97 122 118]
#   ...
#   [ 50  87  83]
#   [ 48  85  83]
#   [ 49  83  82]]
#
#  [[ 97 122 118]
#   [ 97 122 118]
#   [ 97 122 118]
#   ...
#   [ 52  89  85]
#   [ 52  86  85]
#   [ 51  85  84]]
#
#  [[ 95 120 116]
#   [ 94 119 115]
#   [ 94 119 115]
#   ...
#   [ 56  91  87]
#   [ 57  90  86]
#   [ 56  89  85]]]
# 0: 384x640 1 bottle, 144.9ms
# Speed: 2.6ms preprocess, 144.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 351
# [[[147 151 152]
#   [148 152 153]
#   [147 151 152]
#   ...
#   [145 150 149]
#   [142 147 146]
#   [142 147 146]]
#
#  [[147 151 152]
#   [147 151 152]
#   [147 151 152]
#   ...
#   [145 150 149]
#   [143 148 147]
#   [143 148 147]]
#
#  [[148 152 153]
#   [149 153 154]
#   [149 153 154]
#   ...
#   [143 148 147]
#   [143 148 147]
#   [143 148 147]]
#
#  ...
#
#  [[ 98 114 113]
#   [ 97 116 113]
#   [ 97 116 113]
#   ...
#   [ 47  79  78]
#   [ 48  80  79]
#   [ 49  81  80]]
#
#  [[ 94 110 109]
#   [ 96 115 112]
#   [ 96 115 112]
#   ...
#   [ 52  83  80]
#   [ 53  84  81]
#   [ 51  82  79]]
#
#  [[ 96 112 111]
#   [ 95 114 111]
#   [ 96 115 112]
#   ...
#   [ 52  83  80]
#   [ 51  82  79]
#   [ 49  80  77]]]
# 0: 384x640 1 bottle, 130.3ms
# Speed: 2.8ms preprocess, 130.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 350
# [[[148 149 153]
#   [147 148 152]
#   [147 148 152]
#   ...
#   [137 141 142]
#   [137 141 142]
#   [135 139 140]]
#
#  [[149 150 154]
#   [147 148 152]
#   [147 148 152]
#   ...
#   [136 140 141]
#   [136 140 141]
#   [134 138 139]]
#
#  [[149 151 152]
#   [147 149 150]
#   [147 149 150]
#   ...
#   [134 138 139]
#   [134 138 139]
#   [133 137 138]]
#
#  ...
#
#  [[ 89 110 108]
#   [ 88 111 107]
#   [ 85 110 106]
#   ...
#   [ 44  78  78]
#   [ 45  79  79]
#   [ 47  80  83]]
#
#  [[ 90 111 109]
#   [ 88 110 108]
#   [ 85 109 107]
#   ...
#   [ 46  80  80]
#   [ 45  79  79]
#   [ 45  79  79]]
#
#  [[ 90 111 109]
#   [ 90 111 109]
#   [ 88 110 108]
#   ...
#   [ 48  82  82]
#   [ 47  81  81]
#   [ 47  81  81]]]
# 0: 384x640 1 bottle, 133.3ms
# Speed: 2.7ms preprocess, 133.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 357
# [[[154 156 164]
#   [155 157 165]
#   [155 157 165]
#   ...
#   [ 33  46  68]
#   [ 30  41  61]
#   [ 34  44  62]]
#
#  [[155 157 165]
#   [155 157 165]
#   [155 157 165]
#   ...
#   [ 33  44  64]
#   [ 36  46  64]
#   [ 59  69  86]]
#
#  [[156 158 166]
#   [156 158 166]
#   [156 158 166]
#   ...
#   [ 42  54  72]
#   [ 66  76  93]
#   [109 118 132]]
#
#  ...
#
#  [[ 98 116 115]
#   [ 96 117 115]
#   [ 97 118 116]
#   ...
#   [ 48  81  84]
#   [ 48  81  84]
#   [ 47  80  83]]
#
#  [[ 98 116 115]
#   [ 96 117 115]
#   [ 97 118 116]
#   ...
#   [ 49  82  85]
#   [ 49  82  85]
#   [ 48  81  84]]
#
#  [[ 98 116 115]
#   [ 96 117 115]
#   [ 96 117 115]
#   ...
#   [ 50  83  86]
#   [ 52  83  86]
#   [ 51  82  85]]]
# 0: 384x640 (no detections), 130.0ms
# Speed: 3.0ms preprocess, 130.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 129.0ms
# Speed: 3.2ms preprocess, 129.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 395
# [[[27 32 23]
#   [27 32 23]
#   [27 32 23]
#   ...
#   [25 54 28]
#   [25 50 30]
#   [25 48 33]]
#
#  [[27 32 23]
#   [27 32 23]
#   [27 32 23]
#   ...
#   [22 51 25]
#   [26 51 31]
#   [28 49 34]]
#
#  [[27 32 23]
#   [27 32 23]
#   [27 32 23]
#   ...
#   [20 46 22]
#   [28 50 32]
#   [29 50 35]]
#
#  ...
#
#  [[64 70 69]
#   [62 68 67]
#   [59 65 64]
#   ...
#   [45 51 50]
#   [47 52 51]
#   [47 52 51]]
#
#  [[58 63 62]
#   [57 62 61]
#   [56 62 61]
#   ...
#   [46 52 51]
#   [48 53 52]
#   [48 53 52]]
#
#  [[55 60 59]
#   [55 60 59]
#   [55 61 60]
#   ...
#   [48 54 53]
#   [49 54 53]
#   [49 54 53]]]
# 0: 384x640 1 bottle, 153.8ms
# Speed: 6.5ms preprocess, 153.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 266
# [[[150 145 147]
#   [144 139 141]
#   [148 143 145]
#   ...
#   [111 118 173]
#   [112 118 163]
#   [110 116 151]]
#
#  [[150 145 147]
#   [144 139 141]
#   [148 143 145]
#   ...
#   [117 125 178]
#   [117 123 168]
#   [112 121 155]]
#
#  [[147 144 146]
#   [143 140 142]
#   [147 144 146]
#   ...
#   [123 134 186]
#   [123 132 176]
#   [118 128 162]]
#
#  ...
#
#  [[141 141 141]
#   [141 141 141]
#   [142 142 142]
#   ...
#   [139 134 133]
#   [138 133 130]
#   [141 136 133]]
#
#  [[141 141 141]
#   [142 142 142]
#   [141 141 141]
#   ...
#   [141 136 135]
#   [142 137 134]
#   [142 137 134]]
#
#  [[140 140 140]
#   [142 142 142]
#   [141 141 141]
#   ...
#   [138 133 132]
#   [139 134 131]
#   [139 134 131]]]
# 0: 384x640 (no detections), 177.5ms
# Speed: 2.8ms preprocess, 177.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 135.6ms
# Speed: 3.5ms preprocess, 135.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 121.6ms
# Speed: 3.2ms preprocess, 121.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 183.9ms
# Speed: 2.8ms preprocess, 183.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 135.1ms
# Speed: 2.6ms preprocess, 135.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 121.4ms
# Speed: 3.0ms preprocess, 121.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 123.2ms
# Speed: 1.8ms preprocess, 123.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.6ms
# Speed: 2.6ms preprocess, 124.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 121.9ms
# Speed: 1.9ms preprocess, 121.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 125.8ms
# Speed: 2.1ms preprocess, 125.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 356
# [[[162 164 165]
#   [162 164 165]
#   [160 164 165]
#   ...
#   [153 157 158]
#   [153 157 158]
#   [152 156 157]]
#
#  [[162 164 165]
#   [163 165 166]
#   [163 165 166]
#   ...
#   [154 158 159]
#   [154 158 159]
#   [154 158 159]]
#
#  [[165 164 166]
#   [164 166 167]
#   [164 166 167]
#   ...
#   [152 156 157]
#   [153 157 158]
#   [152 156 157]]
#
#  ...
#
#  [[ 98 120 115]
#   [ 97 120 115]
#   [ 96 119 114]
#   ...
#   [ 56  88  87]
#   [ 58  90  89]
#   [ 59  90  89]]
#
#  [[ 97 119 114]
#   [ 97 119 114]
#   [ 95 118 113]
#   ...
#   [ 56  88  87]
#   [ 57  89  88]
#   [ 60  91  90]]
#
#  [[ 96 118 113]
#   [ 96 118 113]
#   [ 96 119 114]
#   ...
#   [ 56  89  85]
#   [ 57  90  86]
#   [ 59  90  87]]]
# 0: 384x640 1 bottle, 121.3ms
# Speed: 3.1ms preprocess, 121.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 352
# [[[157 161 162]
#   [156 160 161]
#   [156 160 161]
#   ...
#   [151 155 156]
#   [150 154 155]
#   [149 153 154]]
#
#  [[160 164 165]
#   [160 164 165]
#   [159 163 164]
#   ...
#   [149 153 154]
#   [148 152 153]
#   [148 152 153]]
#
#  [[157 161 162]
#   [157 161 162]
#   [156 160 161]
#   ...
#   [148 152 153]
#   [147 151 152]
#   [147 151 152]]
#
#  ...
#
#  [[102 120 119]
#   [103 121 120]
#   [103 124 121]
#   ...
#   [ 50  85  88]
#   [ 49  84  87]
#   [ 49  84  87]]
#
#  [[102 118 117]
#   [101 119 118]
#   [101 122 120]
#   ...
#   [ 53  87  87]
#   [ 53  87  87]
#   [ 54  88  88]]
#
#  [[ 99 115 114]
#   [ 98 116 115]
#   [100 118 117]
#   ...
#   [ 55  89  89]
#   [ 56  90  90]
#   [ 56  90  90]]]
# 0: 384x640 1 bottle, 140.5ms
# Speed: 2.4ms preprocess, 140.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 353
# [[[161 163 164]
#   [161 163 164]
#   [160 162 163]
#   ...
#   [154 156 157]
#   [154 156 157]
#   [154 156 157]]
#
#  [[163 162 164]
#   [162 161 163]
#   [161 163 164]
#   ...
#   [155 157 158]
#   [156 158 159]
#   [155 157 158]]
#
#  [[164 163 165]
#   [164 163 165]
#   [159 161 162]
#   ...
#   [154 156 157]
#   [155 157 158]
#   [154 156 157]]
#
#  ...
#
#  [[100 121 119]
#   [101 122 120]
#   [100 121 118]
#   ...
#   [ 48  86  88]
#   [ 49  87  89]
#   [ 50  88  90]]
#
#  [[100 121 119]
#   [100 121 119]
#   [101 122 119]
#   ...
#   [ 53  89  89]
#   [ 50  85  88]
#   [ 51  86  89]]
#
#  [[ 99 120 118]
#   [ 99 120 118]
#   [101 122 119]
#   ...
#   [ 54  90  90]
#   [ 52  87  90]
#   [ 52  87  90]]]
# 0: 384x640 1 bottle, 145.2ms
# Speed: 2.5ms preprocess, 145.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 349
# [[[150 154 155]
#   [150 154 155]
#   [149 153 154]
#   ...
#   [142 147 146]
#   [142 147 146]
#   [142 147 146]]
#
#  [[151 155 156]
#   [150 154 155]
#   [149 153 154]
#   ...
#   [142 147 146]
#   [142 147 146]
#   [142 147 146]]
#
#  [[149 153 154]
#   [148 152 153]
#   [147 151 152]
#   ...
#   [141 146 145]
#   [141 146 145]
#   [141 146 145]]
#
#  ...
#
#  [[ 92 111 108]
#   [ 90 111 108]
#   [ 90 111 108]
#   ...
#   [ 41  79  79]
#   [ 40  78  78]
#   [ 42  78  78]]
#
#  [[ 90 109 106]
#   [ 89 110 107]
#   [ 90 111 108]
#   ...
#   [ 41  79  79]
#   [ 42  78  78]
#   [ 42  78  78]]
#
#  [[ 91 109 108]
#   [ 89 110 108]
#   [ 88 109 107]
#   ...
#   [ 46  83  81]
#   [ 48  82  81]
#   [ 45  79  79]]]
# 0: 384x640 1 bottle, 191.6ms
# Speed: 3.3ms preprocess, 191.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 448
# [[[132 133 131]
#   [131 132 130]
#   [133 134 132]
#   ...
#   [123 123 123]
#   [123 123 123]
#   [125 125 125]]
#
#  [[132 133 131]
#   [131 132 130]
#   [133 134 132]
#   ...
#   [123 123 123]
#   [123 123 123]
#   [124 124 124]]
#
#  [[132 133 131]
#   [132 133 131]
#   [133 134 132]
#   ...
#   [123 123 123]
#   [123 123 123]
#   [124 124 124]]
#
#  ...
#
#  [[128 136 136]
#   [128 136 136]
#   [128 136 136]
#   ...
#   [118 131 129]
#   [118 131 129]
#   [121 132 130]]
#
#  [[128 136 136]
#   [128 136 136]
#   [128 136 136]
#   ...
#   [122 133 131]
#   [122 133 131]
#   [122 133 131]]
#
#  [[128 136 136]
#   [128 136 136]
#   [128 136 136]
#   ...
#   [122 133 131]
#   [122 133 131]
#   [122 133 131]]]
# 0: 384x640 1 bottle, 170.5ms
# Speed: 2.9ms preprocess, 170.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 430
# [[[162 178 247]
#   [169 184 253]
#   [172 187 255]
#   ...
#   [ 52  52  52]
#   [ 42  42  42]
#   [ 49  49  49]]
#
#  [[160 176 245]
#   [168 183 252]
#   [172 187 255]
#   ...
#   [ 49  49  49]
#   [ 40  40  40]
#   [ 48  48  48]]
#
#  [[158 174 243]
#   [166 181 250]
#   [171 186 255]
#   ...
#   [ 49  49  49]
#   [ 39  39  39]
#   [ 47  47  47]]
#
#  ...
#
#  [[ 59  68  65]
#   [ 59  68  65]
#   [ 58  67  64]
#   ...
#   [ 20  46  32]
#   [ 17  46  31]
#   [ 19  45  32]]
#
#  [[ 58  67  64]
#   [ 58  67  64]
#   [ 58  67  64]
#   ...
#   [ 20  46  33]
#   [ 19  45  32]
#   [ 18  44  31]]
#
#  [[ 58  69  67]
#   [ 58  69  67]
#   [ 58  69  67]
#   ...
#   [ 19  43  33]
#   [ 19  43  33]
#   [ 19  43  33]]]
# 0: 384x640 (no detections), 142.2ms
# Speed: 3.2ms preprocess, 142.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 126.1ms
# Speed: 3.0ms preprocess, 126.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 343
# [[[ 64  75 125]
#   [ 62  73 117]
#   [ 55  66 104]
#   ...
#   [117 136 204]
#   [116 135 203]
#   [116 133 200]]
#
#  [[ 55  66 110]
#   [ 53  65 105]
#   [ 50  62  96]
#   ...
#   [118 134 203]
#   [117 134 201]
#   [114 131 198]]
#
#  [[ 53  64 102]
#   [ 52  64  98]
#   [ 49  60  90]
#   ...
#   [117 134 201]
#   [115 132 199]
#   [112 129 196]]
#
#  ...
#
#  [[125 141 140]
#   [125 141 140]
#   [124 140 139]
#   ...
#   [142 158 165]
#   [142 158 165]
#   [144 157 165]]
#
#  [[126 142 141]
#   [126 142 141]
#   [123 139 138]
#   ...
#   [139 155 162]
#   [140 156 163]
#   [141 154 162]]
#
#  [[126 142 141]
#   [127 143 142]
#   [126 142 141]
#   ...
#   [138 154 161]
#   [138 154 161]
#   [140 153 161]]]
# 0: 384x640 (no detections), 134.8ms
# Speed: 3.4ms preprocess, 134.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.3ms
# Speed: 2.5ms preprocess, 133.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 163.9ms
# Speed: 4.6ms preprocess, 163.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 337
# [[[ 94  89  90]
#   [ 96  91  92]
#   [101  95  96]
#   ...
#   [ 21  21  21]
#   [ 22  22  22]
#   [ 22  22  22]]
#
#  [[ 94  89  90]
#   [ 96  91  92]
#   [101  95  96]
#   ...
#   [ 21  21  21]
#   [ 22  22  22]
#   [ 22  22  22]]
#
#  [[ 93  88  89]
#   [ 97  92  93]
#   [101  95  96]
#   ...
#   [ 21  21  21]
#   [ 21  21  21]
#   [ 21  21  21]]
#
#  ...
#
#  [[125 141 140]
#   [125 141 140]
#   [126 142 141]
#   ...
#   [142 157 160]
#   [142 156 162]
#   [146 155 164]]
#
#  [[125 141 140]
#   [125 141 140]
#   [125 141 140]
#   ...
#   [142 157 160]
#   [142 156 162]
#   [145 154 163]]
#
#  [[126 142 141]
#   [125 141 140]
#   [125 141 140]
#   ...
#   [140 156 162]
#   [142 156 162]
#   [144 155 163]]]
# 0: 384x640 (no detections), 151.9ms
# Speed: 2.7ms preprocess, 151.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 134.6ms
# Speed: 2.7ms preprocess, 134.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 200.5ms
# Speed: 7.0ms preprocess, 200.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 154.0ms
# Speed: 3.7ms preprocess, 154.0ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
# 392
# [[[ 98  99  97]
#   [ 93  96  94]
#   [ 86  89  87]
#   ...
#   [113 117 111]
#   [113 117 112]
#   [113 117 112]]
#
#  [[ 96  99  97]
#   [ 94  97  95]
#   [ 87  90  88]
#   ...
#   [113 117 111]
#   [113 117 112]
#   [113 117 112]]
#
#  [[ 96  99  97]
#   [ 94  97  95]
#   [ 86  89  87]
#   ...
#   [113 117 111]
#   [113 117 112]
#   [113 117 112]]
#
#  ...
#
#  [[ 31  42  40]
#   [ 32  43  41]
#   [ 32  43  41]
#   ...
#   [ 97 105  98]
#   [ 97 105  98]
#   [ 97 105  98]]
#
#  [[ 27  38  36]
#   [ 26  37  35]
#   [ 27  38  36]
#   ...
#   [ 98 106  99]
#   [ 98 106  99]
#   [ 98 106  99]]
#
#  [[ 31  42  40]
#   [ 31  42  40]
#   [ 29  40  38]
#   ...
#   [ 98 106  99]
#   [ 98 106  99]
#   [ 98 106  99]]]
# 0: 384x640 1 bottle, 149.5ms
# Speed: 4.2ms preprocess, 149.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 424
# [[[133 133 133]
#   [133 133 133]
#   [134 134 134]
#   ...
#   [120 124 119]
#   [120 124 119]
#   [119 123 118]]
#
#  [[133 133 133]
#   [133 133 133]
#   [134 134 134]
#   ...
#   [120 124 119]
#   [120 124 119]
#   [118 124 119]]
#
#  [[133 133 133]
#   [133 133 133]
#   [134 134 134]
#   ...
#   [118 124 119]
#   [117 123 118]
#   [117 123 118]]
#
#  ...
#
#  [[128 135 138]
#   [128 135 138]
#   [129 136 139]
#   ...
#   [122 132 132]
#   [121 131 131]
#   [121 131 131]]
#
#  [[129 136 139]
#   [129 136 139]
#   [129 136 139]
#   ...
#   [122 132 132]
#   [122 132 132]
#   [121 131 131]]
#
#  [[128 135 138]
#   [128 135 138]
#   [128 135 138]
#   ...
#   [123 131 131]
#   [122 130 130]
#   [122 130 130]]]
# 0: 384x640 1 bottle, 341.9ms
# Speed: 32.3ms preprocess, 341.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# 349
# [[[148 150 151]
#   [148 150 151]
#   [149 151 152]
#   ...
#   [142 146 147]
#   [142 146 147]
#   [143 147 148]]
#
#  [[153 155 156]
#   [151 153 154]
#   [150 152 153]
#   ...
#   [141 145 146]
#   [141 145 146]
#   [141 145 146]]
#
#  [[153 155 156]
#   [151 153 154]
#   [150 152 153]
#   ...
#   [140 144 145]
#   [140 144 145]
#   [140 144 145]]
#
#  ...
#
#  [[ 91 112 110]
#   [ 90 111 109]
#   [ 88 110 108]
#   ...
#   [ 41  79  81]
#   [ 39  77  79]
#   [ 43  78  81]]
#
#  [[ 92 110 109]
#   [ 89 110 108]
#   [ 87 109 107]
#   ...
#   [ 40  78  80]
#   [ 41  76  79]
#   [ 43  78  81]]
#
#  [[ 91 109 108]
#   [ 88 109 107]
#   [ 88 109 107]
#   ...
#   [ 42  78  78]
#   [ 45  79  79]
#   [ 46  80  80]]]
# 0: 384x640 1 bottle, 184.4ms
# Speed: 5.0ms preprocess, 184.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 353
# [[[162 161 163]
#   [162 161 163]
#   [163 162 164]
#   ...
#   [151 155 156]
#   [152 156 157]
#   [152 156 157]]
#
#  [[162 161 163]
#   [163 162 164]
#   [162 161 163]
#   ...
#   [151 155 156]
#   [152 156 157]
#   [152 156 157]]
#
#  [[164 163 165]
#   [164 163 165]
#   [164 163 165]
#   ...
#   [150 154 155]
#   [150 154 155]
#   [150 154 155]]
#
#  ...
#
#  [[100 121 119]
#   [ 98 119 117]
#   [100 121 118]
#   ...
#   [ 49  87  89]
#   [ 49  87  89]
#   [ 48  86  88]]
#
#  [[100 121 119]
#   [ 98 119 117]
#   [101 122 119]
#   ...
#   [ 53  89  89]
#   [ 52  88  88]
#   [ 52  88  88]]
#
#  [[ 99 120 118]
#   [ 97 118 116]
#   [ 99 120 117]
#   ...
#   [ 57  91  91]
#   [ 56  90  90]
#   [ 54  90  90]]]
# 0: 384x640 1 bottle, 131.2ms
# Speed: 2.8ms preprocess, 131.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 370
# [[[126 137 135]
#   [127 138 136]
#   [131 139 138]
#   ...
#   [176 175 177]
#   [176 175 177]
#   [175 174 176]]
#
#  [[127 138 136]
#   [131 142 140]
#   [137 145 144]
#   ...
#   [175 174 176]
#   [175 174 176]
#   [175 174 176]]
#
#  [[138 149 147]
#   [142 153 151]
#   [148 156 155]
#   ...
#   [174 173 175]
#   [174 173 175]
#   [174 173 175]]
#
#  ...
#
#  [[114 128 126]
#   [111 128 125]
#   [111 128 125]
#   ...
#   [ 39 103  98]
#   [ 40 101  97]
#   [ 41 100  96]]
#
#  [[115 129 127]
#   [111 128 125]
#   [110 127 124]
#   ...
#   [ 40 104  99]
#   [ 38 102  97]
#   [ 41 100  96]]
#
#  [[115 129 127]
#   [111 128 125]
#   [112 126 124]
#   ...
#   [ 39 102 100]
#   [ 38 101  99]
#   [ 40  98  97]]]
# 0: 384x640 1 bottle, 141.5ms
# Speed: 3.4ms preprocess, 141.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 324
# [[[164 163 167]
#   [164 163 167]
#   [165 164 168]
#   ...
#   [154 158 159]
#   [154 158 159]
#   [153 157 158]]
#
#  [[166 165 167]
#   [166 165 169]
#   [165 164 168]
#   ...
#   [153 157 158]
#   [153 157 158]
#   [153 157 158]]
#
#  [[169 168 170]
#   [169 168 172]
#   [169 168 172]
#   ...
#   [153 157 158]
#   [153 157 158]
#   [153 157 158]]
#
#  ...
#
#  [[100 118 117]
#   [100 118 117]
#   [101 119 118]
#   ...
#   [ 43  80  78]
#   [ 44  78  77]
#   [ 44  78  77]]
#
#  [[101 119 118]
#   [101 119 118]
#   [102 120 119]
#   ...
#   [ 44  81  79]
#   [ 46  80  79]
#   [ 46  80  79]]
#
#  [[102 118 117]
#   [100 118 117]
#   [100 118 117]
#   ...
#   [ 46  80  79]
#   [ 48  80  79]
#   [ 48  80  79]]]
# 0: 384x640 1 bottle, 137.1ms
# Speed: 4.2ms preprocess, 137.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 348
# [[[156 154 160]
#   [156 154 160]
#   [155 153 159]
#   ...
#   [ 55  67 107]
#   [ 58  70 110]
#   [ 58  70 110]]
#
#  [[157 155 161]
#   [157 155 161]
#   [156 154 160]
#   ...
#   [ 56  68 108]
#   [ 54  66 106]
#   [ 54  66 106]]
#
#  [[160 158 164]
#   [160 158 164]
#   [156 154 160]
#   ...
#   [ 54  66 106]
#   [ 53  65 105]
#   [ 53  65 105]]
#
#  ...
#
#  [[ 95 107 107]
#   [ 95 107 107]
#   [ 94 106 106]
#   ...
#   [ 53  82  79]
#   [ 56  83  80]
#   [ 56  83  80]]
#
#  [[ 95 107 107]
#   [ 95 107 107]
#   [ 95 107 107]
#   ...
#   [ 55  84  81]
#   [ 57  84  81]
#   [ 57  84  81]]
#
#  [[ 95 107 107]
#   [ 95 107 107]
#   [ 96 108 108]
#   ...
#   [ 58  85  82]
#   [ 58  85  82]
#   [ 58  85  82]]]
# 0: 384x640 1 bottle, 151.5ms
# Speed: 4.7ms preprocess, 151.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 230
# [[[ 13  18  17]
#   [ 12  17  16]
#   [ 12  17  16]
#   ...
#   [ 29  37  30]
#   [ 29  37  30]
#   [ 31  37  32]]
#
#  [[ 13  18  17]
#   [ 12  17  16]
#   [ 12  17  16]
#   ...
#   [ 29  37  30]
#   [ 29  37  30]
#   [ 31  37  32]]
#
#  [[ 13  18  17]
#   [ 12  17  16]
#   [ 12  17  16]
#   ...
#   [ 30  38  31]
#   [ 30  38  31]
#   [ 30  38  31]]
#
#  ...
#
#  [[ 92 108 107]
#   [ 94 111 108]
#   [ 94 113 110]
#   ...
#   [ 97 125 119]
#   [ 98 123 119]
#   [ 98 119 120]]
#
#  [[ 94 110 109]
#   [ 94 111 108]
#   [ 95 114 111]
#   ...
#   [ 98 124 118]
#   [ 99 122 118]
#   [ 99 119 120]]
#
#  [[ 99 113 111]
#   [ 96 113 110]
#   [ 96 116 111]
#   ...
#   [ 98 123 119]
#   [ 99 122 118]
#   [ 99 119 120]]]
# 0: 384x640 1 bottle, 132.0ms
# Speed: 2.0ms preprocess, 132.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 519
# [[[ 67  86 124]
#   [ 67  86 123]
#   [ 71  90 127]
#   ...
#   [ 90  86  91]
#   [ 90  86  91]
#   [ 89  85  90]]
#
#  [[ 71  90 128]
#   [ 69  88 125]
#   [ 71  90 127]
#   ...
#   [ 90  86  91]
#   [ 88  87  91]
#   [ 90  86  91]]
#
#  [[ 73  92 130]
#   [ 69  90 128]
#   [ 70  91 129]
#   ...
#   [ 89  88  92]
#   [ 86  87  91]
#   [ 88  87  91]]
#
#  ...
#
#  [[126 128 128]
#   [126 128 128]
#   [126 128 128]
#   ...
#   [ 92 100  99]
#   [ 92 100  99]
#   [ 93 101 100]]
#
#  [[128 130 130]
#   [128 130 130]
#   [128 130 130]
#   ...
#   [ 91  99  98]
#   [ 91  99  98]
#   [ 92 100  99]]
#
#  [[128 130 130]
#   [128 130 130]
#   [128 130 130]
#   ...
#   [ 89 100  98]
#   [ 89 100  98]
#   [ 89 100  98]]]
# 0: 384x640 (no detections), 139.2ms
# Speed: 2.9ms preprocess, 139.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 122.7ms
# Speed: 3.3ms preprocess, 122.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 134.3ms
# Speed: 3.1ms preprocess, 134.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 380
# [[[141 141 141]
#   [141 141 141]
#   [141 141 141]
#   ...
#   [136 136 136]
#   [137 137 137]
#   [137 137 137]]
#
#  [[145 145 145]
#   [145 145 145]
#   [146 146 146]
#   ...
#   [137 137 137]
#   [138 138 138]
#   [138 138 138]]
#
#  [[148 148 148]
#   [148 148 148]
#   [148 148 148]
#   ...
#   [138 138 138]
#   [139 139 139]
#   [139 139 139]]
#
#  ...
#
#  [[ 39  71  60]
#   [ 40  74  63]
#   [ 40  76  62]
#   ...
#   [ 16  72  67]
#   [ 24  69  66]
#   [ 31  68  66]]
#
#  [[ 39  71  60]
#   [ 42  74  63]
#   [ 39  75  61]
#   ...
#   [  9  65  60]
#   [ 22  67  64]
#   [ 29  66  64]]
#
#  [[ 42  72  59]
#   [ 44  74  61]
#   [ 40  76  60]
#   ...
#   [ 12  68  63]
#   [ 22  67  64]
#   [ 27  64  62]]]
# 0: 384x640 (no detections), 180.1ms
# Speed: 2.2ms preprocess, 180.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 289.5ms
# Speed: 4.1ms preprocess, 289.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 366
# [[[170 169 171]
#   [170 169 171]
#   [170 169 171]
#   ...
#   [161 159 165]
#   [161 159 165]
#   [160 158 164]]
#
#  [[170 169 171]
#   [170 169 171]
#   [170 169 171]
#   ...
#   [160 158 164]
#   [160 158 164]
#   [160 158 164]]
#
#  [[169 168 170]
#   [169 168 170]
#   [169 168 170]
#   ...
#   [158 156 162]
#   [159 157 163]
#   [160 158 164]]
#
#  ...
#
#  [[107 119 119]
#   [108 120 120]
#   [109 121 121]
#   ...
#   [ 28  86  85]
#   [ 37  87  85]
#   [ 41  85  84]]
#
#  [[107 119 119]
#   [108 120 120]
#   [109 121 121]
#   ...
#   [ 32  89  88]
#   [ 40  89  87]
#   [ 43  85  84]]
#
#  [[110 120 120]
#   [111 121 121]
#   [110 122 122]
#   ...
#   [ 33  87  87]
#   [ 38  87  85]
#   [ 41  83  82]]]
# 0: 384x640 1 bottle, 168.6ms
# Speed: 8.3ms preprocess, 168.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 237
# [[[ 53  53  53]
#   [ 53  53  53]
#   [ 54  54  54]
#   ...
#   [ 83  93 103]
#   [ 83  93 103]
#   [ 82  92 102]]
#
#  [[ 54  54  54]
#   [ 53  53  53]
#   [ 54  54  54]
#   ...
#   [ 86  95 104]
#   [ 86  95 104]
#   [ 85  94 104]]
#
#  [[ 54  54  54]
#   [ 53  53  53]
#   [ 54  54  54]
#   ...
#   [ 85  92 101]
#   [ 85  92 101]
#   [ 82  91 100]]
#
#  ...
#
#  [[127 148 146]
#   [127 149 147]
#   [126 150 148]
#   ...
#   [128 140 142]
#   [134 146 146]
#   [133 145 145]]
#
#  [[131 152 150]
#   [129 151 149]
#   [128 152 150]
#   ...
#   [130 142 144]
#   [131 143 143]
#   [131 143 143]]
#
#  [[128 146 145]
#   [126 147 145]
#   [127 149 147]
#   ...
#   [132 144 146]
#   [133 145 145]
#   [133 145 145]]]
# 0: 384x640 1 bottle, 141.9ms
# Speed: 3.1ms preprocess, 141.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 352
# [[[135 133 133]
#   [135 133 133]
#   [135 133 133]
#   ...
#   [ 28  28  28]
#   [ 27  27  27]
#   [ 28  28  28]]
#
#  [[135 133 133]
#   [135 133 133]
#   [135 133 133]
#   ...
#   [ 29  29  29]
#   [ 27  26  28]
#   [ 29  28  30]]
#
#  [[135 133 133]
#   [135 133 133]
#   [135 133 133]
#   ...
#   [ 29  29  29]
#   [ 27  26  28]
#   [ 28  27  29]]
#
#  ...
#
#  [[127 135 134]
#   [130 136 135]
#   [129 137 136]
#   ...
#   [126 142 141]
#   [127 141 140]
#   [127 141 140]]
#
#  [[131 139 138]
#   [134 140 139]
#   [134 140 139]
#   ...
#   [128 144 143]
#   [130 144 143]
#   [130 144 143]]
#
#  [[133 141 140]
#   [135 141 140]
#   [135 141 140]
#   ...
#   [133 147 146]
#   [133 147 146]
#   [134 148 147]]]
# 0: 384x640 1 bottle, 247.4ms
# Speed: 3.0ms preprocess, 247.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 363
# [[[168 167 169]
#   [169 168 170]
#   [169 168 170]
#   ...
#   [158 157 159]
#   [159 158 160]
#   [159 158 160]]
#
#  [[167 166 168]
#   [168 167 169]
#   [168 167 169]
#   ...
#   [157 156 158]
#   [157 156 158]
#   [158 157 159]]
#
#  [[167 166 168]
#   [167 166 168]
#   [167 166 168]
#   ...
#   [159 158 160]
#   [158 157 159]
#   [159 158 160]]
#
#  ...
#
#  [[108 118 118]
#   [108 118 118]
#   [105 118 116]
#   ...
#   [ 11  91  86]
#   [ 18  85  80]
#   [ 27  84  81]]
#
#  [[109 119 119]
#   [108 118 118]
#   [106 118 118]
#   ...
#   [  7  83  79]
#   [ 21  87  82]
#   [ 29  86  83]]
#
#  [[109 119 119]
#   [109 119 119]
#   [107 119 119]
#   ...
#   [  9  83  79]
#   [ 26  90  85]
#   [ 31  86  83]]]
# 0: 384x640 (no detections), 159.4ms
# Speed: 4.1ms preprocess, 159.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 141.5ms
# Speed: 2.1ms preprocess, 141.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 131.0ms
# Speed: 2.3ms preprocess, 131.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 701
# [[[ 98 106 106]
#   [ 96 107 105]
#   [ 95 108 106]
#   ...
#   [ 35  80  71]
#   [ 43  79  73]
#   [ 49  76  73]]
#
#  [[ 98 106 105]
#   [ 96 107 104]
#   [ 95 109 105]
#   ...
#   [ 34  75  67]
#   [ 40  73  66]
#   [ 47  72  68]]
#
#  [[ 98 107 104]
#   [ 97 109 103]
#   [ 95 109 103]
#   ...
#   [ 37  74  64]
#   [ 41  72  63]
#   [ 48  71  66]]
#
#  ...
#
#  [[ 43  51  51]
#   [ 43  51  51]
#   [ 41  51  51]
#   ...
#   [ 22  44  50]
#   [ 22  44  50]
#   [ 20  42  48]]
#
#  [[ 42  51  54]
#   [ 42  51  54]
#   [ 42  52  52]
#   ...
#   [ 24  43  51]
#   [ 24  43  51]
#   [ 24  43  51]]
#
#  [[ 43  52  55]
#   [ 43  52  55]
#   [ 43  53  53]
#   ...
#   [ 24  43  51]
#   [ 24  43  51]
#   [ 24  43  51]]]
# 0: 384x640 1 bottle, 138.9ms
# Speed: 2.8ms preprocess, 138.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 228
# [[[ 42  41  43]
#   [ 30  30  30]
#   [ 37  37  37]
#   ...
#   [111 130 181]
#   [114 133 184]
#   [110 131 182]]
#
#  [[ 40  39  41]
#   [ 32  32  32]
#   [ 35  37  37]
#   ...
#   [106 125 176]
#   [105 124 175]
#   [103 124 175]]
#
#  [[ 40  40  40]
#   [ 31  33  33]
#   [ 34  36  36]
#   ...
#   [107 125 178]
#   [106 124 177]
#   [105 126 177]]
#
#  ...
#
#  [[105 124 121]
#   [101 124 120]
#   [100 125 121]
#   ...
#   [108 122 121]
#   [107 121 120]
#   [108 120 120]]
#
#  [[107 124 121]
#   [102 124 119]
#   [102 125 120]
#   ...
#   [108 121 119]
#   [108 121 119]
#   [107 119 119]]
#
#  [[110 124 122]
#   [106 126 121]
#   [105 127 122]
#   ...
#   [107 120 118]
#   [107 120 118]
#   [107 119 119]]]
# 0: 384x640 1 bottle, 134.0ms
# Speed: 2.3ms preprocess, 134.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 415
# [[[113 116 120]
#   [114 117 121]
#   [114 117 122]
#   ...
#   [107 116 126]
#   [109 115 126]
#   [109 115 126]]
#
#  [[113 116 120]
#   [113 116 120]
#   [114 117 121]
#   ...
#   [106 115 124]
#   [108 115 124]
#   [108 115 124]]
#
#  [[113 116 120]
#   [113 116 120]
#   [113 116 120]
#   ...
#   [105 115 122]
#   [107 115 122]
#   [107 115 122]]
#
#  ...
#
#  [[204 200 199]
#   [205 201 200]
#   [205 201 200]
#   ...
#   [163 164 155]
#   [164 165 156]
#   [164 165 156]]
#
#  [[197 195 194]
#   [198 196 195]
#   [201 197 196]
#   ...
#   [163 164 155]
#   [163 164 155]
#   [164 165 156]]
#
#  [[196 194 193]
#   [195 193 192]
#   [197 193 192]
#   ...
#   [163 164 155]
#   [163 163 157]
#   [164 165 156]]]
# 0: 384x640 (no detections), 162.0ms
# Speed: 2.4ms preprocess, 162.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 133.5ms
# Speed: 3.0ms preprocess, 133.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 347
# [[[156 155 157]
#   [156 155 157]
#   [156 155 157]
#   ...
#   [151 150 152]
#   [151 150 152]
#   [152 151 153]]
#
#  [[156 155 157]
#   [156 155 157]
#   [156 155 157]
#   ...
#   [148 147 149]
#   [148 147 149]
#   [149 148 150]]
#
#  [[153 152 154]
#   [153 152 154]
#   [153 152 154]
#   ...
#   [147 146 148]
#   [146 145 147]
#   [146 145 147]]
#
#  ...
#
#  [[ 97 111 109]
#   [ 97 111 109]
#   [ 97 111 109]
#   ...
#   [ 60  86  86]
#   [ 59  85  85]
#   [ 59  85  85]]
#
#  [[ 95 109 107]
#   [ 94 108 106]
#   [ 95 109 107]
#   ...
#   [ 61  87  87]
#   [ 61  87  87]
#   [ 60  86  86]]
#
#  [[ 92 106 104]
#   [ 93 107 105]
#   [ 93 107 105]
#   ...
#   [ 63  90  87]
#   [ 62  89  86]
#   [ 63  87  87]]]
# 0: 384x640 1 bottle, 144.8ms
# Speed: 2.6ms preprocess, 144.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 323
# [[[158 162 163]
#   [158 162 163]
#   [158 162 163]
#   ...
#   [150 154 155]
#   [152 156 157]
#   [152 156 157]]
#
#  [[162 164 165]
#   [161 163 164]
#   [161 163 164]
#   ...
#   [151 155 156]
#   [151 155 156]
#   [151 155 156]]
#
#  [[163 165 166]
#   [163 165 166]
#   [163 165 166]
#   ...
#   [152 156 157]
#   [152 156 157]
#   [151 155 156]]
#
#  ...
#
#  [[100 117 114]
#   [ 98 116 115]
#   [ 98 116 115]
#   ...
#   [ 48  83  79]
#   [ 50  83  79]
#   [ 48  81  77]]
#
#  [[ 98 115 112]
#   [ 97 115 114]
#   [ 99 117 116]
#   ...
#   [ 43  78  74]
#   [ 46  79  75]
#   [ 48  79  76]]
#
#  [[100 117 114]
#   [ 99 117 116]
#   [100 118 117]
#   ...
#   [ 45  78  74]
#   [ 47  78  75]
#   [ 48  79  76]]]
# 0: 384x640 1 bottle, 135.0ms
# Speed: 3.0ms preprocess, 135.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 368
# [[[137 143 142]
#   [140 146 145]
#   [142 148 147]
#   ...
#   [175 174 176]
#   [175 174 176]
#   [174 173 175]]
#
#  [[157 163 162]
#   [156 162 161]
#   [155 161 160]
#   ...
#   [175 174 176]
#   [175 174 176]
#   [175 174 176]]
#
#  [[158 164 163]
#   [157 163 162]
#   [158 164 163]
#   ...
#   [175 174 176]
#   [175 174 176]
#   [175 174 176]]
#
#  ...
#
#  [[111 128 125]
#   [111 128 125]
#   [110 126 125]
#   ...
#   [ 43 100  97]
#   [ 45  99  99]
#   [ 47  99  99]]
#
#  [[111 127 126]
#   [110 126 125]
#   [110 126 125]
#   ...
#   [ 43 100  97]
#   [ 44  98  98]
#   [ 44  98  98]]
#
#  [[111 127 126]
#   [111 127 126]
#   [111 127 126]
#   ...
#   [ 43 102  98]
#   [ 44  98  98]
#   [ 43  97  97]]]
# 0: 384x640 1 bottle, 135.1ms
# Speed: 3.1ms preprocess, 135.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 293
# [[[120 120 120]
#   [115 115 115]
#   [109 109 109]
#   ...
#   [ 52  69 102]
#   [ 49  66  99]
#   [ 48  65  98]]
#
#  [[120 120 120]
#   [115 115 115]
#   [109 109 109]
#   ...
#   [ 49  66  99]
#   [ 48  65  98]
#   [ 47  64  97]]
#
#  [[120 120 120]
#   [117 117 117]
#   [110 110 110]
#   ...
#   [ 49  64  96]
#   [ 48  63  95]
#   [ 48  63  95]]
#
#  ...
#
#  [[117 131 130]
#   [122 136 135]
#   [120 134 133]
#   ...
#   [152 160 159]
#   [152 160 159]
#   [150 158 157]]
#
#  [[116 130 129]
#   [122 136 135]
#   [120 134 133]
#   ...
#   [152 160 159]
#   [152 160 159]
#   [150 158 157]]
#
#  [[116 130 129]
#   [122 136 135]
#   [120 134 133]
#   ...
#   [152 160 159]
#   [152 160 159]
#   [150 158 157]]]
# 0: 384x640 1 bottle, 127.8ms
# Speed: 2.7ms preprocess, 127.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 319
# [[[171 173 181]
#   [170 172 180]
#   [169 171 179]
#   ...
#   [ 78  89 133]
#   [ 75  88 132]
#   [ 71  84 128]]
#
#  [[171 173 181]
#   [170 172 180]
#   [170 172 180]
#   ...
#   [ 71  84 130]
#   [ 68  81 127]
#   [ 64  77 123]]
#
#  [[170 172 180]
#   [170 172 180]
#   [170 172 180]
#   ...
#   [ 64  76 124]
#   [ 60  72 120]
#   [ 56  68 116]]
#
#  ...
#
#  [[ 97 117 112]
#   [ 97 117 112]
#   [ 95 117 112]
#   ...
#   [ 61  95  94]
#   [ 63  95  94]
#   [ 62  94  93]]
#
#  [[ 97 116 113]
#   [ 99 118 115]
#   [ 97 118 115]
#   ...
#   [ 64  97  93]
#   [ 65  96  93]
#   [ 65  96  93]]
#
#  [[ 98 115 112]
#   [ 98 117 114]
#   [ 98 117 114]
#   ...
#   [ 66  97  94]
#   [ 66  97  94]
#   [ 66  97  94]]]
# 0: 384x640 1 bottle, 128.6ms
# Speed: 2.5ms preprocess, 128.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 346
# [[[141 146 145]
#   [143 148 147]
#   [144 149 148]
#   ...
#   [141 141 141]
#   [141 141 141]
#   [140 140 140]]
#
#  [[139 144 143]
#   [140 145 144]
#   [142 147 146]
#   ...
#   [138 138 138]
#   [138 138 138]
#   [137 137 137]]
#
#  [[139 144 143]
#   [140 145 144]
#   [140 145 144]
#   ...
#   [139 139 139]
#   [138 138 138]
#   [138 138 138]]
#
#  ...
#
#  [[ 87 106 103]
#   [ 85 107 102]
#   [ 84 107 102]
#   ...
#   [ 34  69  65]
#   [ 36  69  65]
#   [ 35  68  64]]
#
#  [[ 87 106 103]
#   [ 85 107 102]
#   [ 84 107 102]
#   ...
#   [ 36  69  65]
#   [ 37  68  65]
#   [ 37  68  65]]
#
#  [[ 86 105 102]
#   [ 85 107 102]
#   [ 85 107 102]
#   ...
#   [ 36  69  65]
#   [ 37  68  65]
#   [ 37  68  65]]]
# 0: 384x640 (no detections), 136.4ms
# Speed: 2.7ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 127.6ms
# Speed: 3.2ms preprocess, 127.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 125.5ms
# Speed: 3.0ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 528
# [[[ 70  83 115]
#   [ 68  83 116]
#   [ 65  81 117]
#   ...
#   [ 70  78  95]
#   [ 67  77  95]
#   [ 69  80 100]]
#
#  [[ 69  83 112]
#   [ 67  82 114]
#   [ 66  81 114]
#   ...
#   [ 72  82 100]
#   [ 70  81 101]
#   [ 62  75  97]]
#
#  [[ 67  81 110]
#   [ 64  79 111]
#   [ 64  79 112]
#   ...
#   [ 70  82 100]
#   [ 67  81 100]
#   [ 65  79 101]]
#
#  ...
#
#  [[106 111 114]
#   [106 111 114]
#   [107 110 114]
#   ...
#   [ 40  61  59]
#   [ 32  53  51]
#   [ 25  45  46]]
#
#  [[108 112 113]
#   [107 111 112]
#   [107 111 112]
#   ...
#   [ 40  61  59]
#   [ 36  57  55]
#   [ 29  49  50]]
#
#  [[108 112 113]
#   [107 111 112]
#   [107 111 112]
#   ...
#   [ 32  53  51]
#   [ 33  54  52]
#   [ 31  51  52]]]
# 0: 384x640 (no detections), 178.2ms
# Speed: 4.6ms preprocess, 178.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 131.2ms
# Speed: 5.3ms preprocess, 131.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 383
# [[[162 159 155]
#   [161 159 158]
#   [161 159 158]
#   ...
#   [137 138 136]
#   [137 138 136]
#   [137 138 136]]
#
#  [[154 151 147]
#   [153 151 150]
#   [153 151 150]
#   ...
#   [133 134 132]
#   [133 134 132]
#   [134 135 133]]
#
#  [[146 142 141]
#   [145 143 143]
#   [145 143 143]
#   ...
#   [127 128 126]
#   [127 128 126]
#   [126 127 125]]
#
#  ...
#
#  [[ 53  82  66]
#   [ 46  83  63]
#   [ 46  91  65]
#   ...
#   [ 18  59  54]
#   [ 21  61  56]
#   [ 20  57  53]]
#
#  [[ 51  80  65]
#   [ 45  82  62]
#   [ 43  85  62]
#   ...
#   [ 19  60  55]
#   [ 22  62  57]
#   [ 22  59  55]]
#
#  [[ 46  77  62]
#   [ 46  80  63]
#   [ 38  79  58]
#   ...
#   [ 20  61  56]
#   [ 22  62  57]
#   [ 23  60  56]]]
# 0: 384x640 1 bottle, 141.1ms
# Speed: 5.2ms preprocess, 141.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 291
# [[[104  98  99]
#   [103  98  97]
#   [104  99  98]
#   ...
#   [ 16  20  15]
#   [ 16  20  15]
#   [ 16  20  15]]
#
#  [[103  97  98]
#   [103  98  97]
#   [104  99  98]
#   ...
#   [ 16  20  15]
#   [ 16  20  15]
#   [ 16  20  15]]
#
#  [[104  98  99]
#   [103  98  97]
#   [103  98  97]
#   ...
#   [ 16  20  15]
#   [ 16  20  15]
#   [ 16  20  15]]
#
#  ...
#
#  [[115 126 124]
#   [114 125 123]
#   [116 127 125]
#   ...
#   [112 133 131]
#   [115 131 130]
#   [116 132 131]]
#
#  [[114 125 123]
#   [113 124 122]
#   [114 125 123]
#   ...
#   [113 134 132]
#   [116 132 131]
#   [117 133 132]]
#
#  [[113 124 122]
#   [111 122 120]
#   [113 124 122]
#   ...
#   [115 133 132]
#   [117 133 132]
#   [118 134 133]]]
# 0: 384x640 (no detections), 142.1ms
# Speed: 2.7ms preprocess, 142.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 132.7ms
# Speed: 3.3ms preprocess, 132.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 317
# [[[141 143 143]
#   [141 143 143]
#   [140 145 144]
#   ...
#   [132 137 136]
#   [136 138 138]
#   [137 139 139]]
#
#  [[140 142 142]
#   [141 143 143]
#   [139 144 143]
#   ...
#   [133 138 137]
#   [136 138 138]
#   [138 140 140]]
#
#  [[139 144 143]
#   [139 144 143]
#   [139 144 143]
#   ...
#   [132 137 136]
#   [134 136 136]
#   [135 137 137]]
#
#  ...
#
#  [[ 68  87  84]
#   [ 69  88  85]
#   [ 70  90  85]
#   ...
#   [ 39  68  65]
#   [ 37  68  65]
#   [ 37  68  65]]
#
#  [[ 67  86  83]
#   [ 67  86  83]
#   [ 68  88  83]
#   ...
#   [ 41  70  67]
#   [ 43  72  69]
#   [ 40  71  68]]
#
#  [[ 67  86  83]
#   [ 67  86  83]
#   [ 69  89  84]
#   ...
#   [ 46  75  72]
#   [ 46  75  72]
#   [ 45  74  71]]]
# 0: 384x640 1 bottle, 162.2ms
# Speed: 3.5ms preprocess, 162.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 322
# [[[ 62  74 122]
#   [ 62  74 122]
#   [ 52  64 112]
#   ...
#   [ 48  63  89]
#   [ 50  65  91]
#   [ 51  67  90]]
#
#  [[ 65  77 125]
#   [ 66  78 126]
#   [ 56  68 116]
#   ...
#   [ 50  65  91]
#   [ 52  67  93]
#   [ 53  69  92]]
#
#  [[ 67  79 127]
#   [ 65  77 125]
#   [ 61  73 121]
#   ...
#   [ 52  67  93]
#   [ 54  69  95]
#   [ 56  72  95]]
#
#  ...
#
#  [[ 74  86  86]
#   [ 73  85  85]
#   [ 72  84  84]
#   ...
#   [ 39  72  68]
#   [ 39  70  67]
#   [ 40  69  66]]
#
#  [[ 73  85  85]
#   [ 72  84  84]
#   [ 72  84  84]
#   ...
#   [ 40  71  68]
#   [ 41  70  67]
#   [ 40  69  66]]
#
#  [[ 72  84  84]
#   [ 71  83  83]
#   [ 71  83  83]
#   ...
#   [ 41  70  67]
#   [ 41  70  67]
#   [ 42  69  66]]]
# 0: 384x640 1 bottle, 145.1ms
# Speed: 6.7ms preprocess, 145.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 323
# [[[148 136 136]
#   [148 136 136]
#   [148 136 136]
#   ...
#   [  5  25  42]
#   [  5  28  44]
#   [  7  30  45]]
#
#  [[149 135 136]
#   [148 136 136]
#   [148 136 136]
#   ...
#   [  4  23  36]
#   [  3  25  37]
#   [  6  25  38]]
#
#  [[149 136 134]
#   [149 136 134]
#   [148 134 135]
#   ...
#   [  5  24  32]
#   [  3  24  32]
#   [  6  25  33]]
#
#  ...
#
#  [[111 124 122]
#   [111 124 122]
#   [111 124 122]
#   ...
#   [129 141 141]
#   [130 142 142]
#   [131 143 145]]
#
#  [[115 126 124]
#   [113 126 124]
#   [113 126 124]
#   ...
#   [130 142 144]
#   [130 142 144]
#   [131 143 145]]
#
#  [[118 129 126]
#   [117 128 125]
#   [117 128 126]
#   ...
#   [134 143 147]
#   [134 143 147]
#   [134 143 147]]]
# 0: 384x640 (no detections), 156.3ms
# Speed: 4.2ms preprocess, 156.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 132.1ms
# Speed: 2.6ms preprocess, 132.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 383
# [[[148 146 146]
#   [147 145 145]
#   [146 144 144]
#   ...
#   [116 121 112]
#   [117 122 113]
#   [117 122 113]]
#
#  [[152 150 150]
#   [151 149 149]
#   [150 148 148]
#   ...
#   [113 121 111]
#   [116 121 112]
#   [116 121 112]]
#
#  [[144 142 142]
#   [143 141 141]
#   [142 140 140]
#   ...
#   [110 118 108]
#   [113 118 109]
#   [113 118 109]]
#
#  ...
#
#  [[ 36  65  56]
#   [ 38  65  56]
#   [ 38  65  56]
#   ...
#   [ 26  46  47]
#   [ 26  46  47]
#   [ 25  45  46]]
#
#  [[ 40  69  60]
#   [ 37  66  57]
#   [ 36  65  56]
#   ...
#   [ 27  48  49]
#   [ 26  47  45]
#   [ 25  46  44]]
#
#  [[ 39  68  59]
#   [ 39  68  59]
#   [ 39  68  59]
#   ...
#   [ 24  45  46]
#   [ 26  47  45]
#   [ 26  47  45]]]
# 0: 384x640 (no detections), 117.0ms
# Speed: 2.1ms preprocess, 117.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 190.1ms
# Speed: 5.9ms preprocess, 190.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 497
# [[[107 112 111]
#   [106 112 111]
#   [105 111 110]
#   ...
#   [ 89  96  89]
#   [ 89  96  89]
#   [ 89  96  89]]
#
#  [[107 112 111]
#   [106 112 111]
#   [105 111 110]
#   ...
#   [ 90  97  90]
#   [ 89  96  89]
#   [ 89  96  89]]
#
#  [[108 113 111]
#   [107 113 112]
#   [106 112 111]
#   ...
#   [ 92  96  90]
#   [ 92  96  90]
#   [ 92  96  90]]
#
#  ...
#
#  [[149 148 144]
#   [151 147 146]
#   [151 147 146]
#   ...
#   [105 114 111]
#   [105 114 111]
#   [105 114 111]]
#
#  [[149 148 144]
#   [151 147 146]
#   [151 147 146]
#   ...
#   [105 114 111]
#   [105 114 111]
#   [104 113 110]]
#
# ...
#  [[ 76  85  82]
#   [ 75  84  81]
#   [ 75  84  81]
#   ...
#   [ 98 101  99]
#   [ 98 101  99]
#   [ 97 100  98]]]
# 0: 384x640 1 bottle, 193.1ms
# Speed: 3.5ms preprocess, 193.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 563
# [[[165 163 169]
#   [165 163 169]
#   [165 163 169]
#   ...
#   [158 157 161]
#   [158 157 161]
#   [158 157 161]]
#
#  [[165 163 169]
#   [164 162 168]
#   [164 162 168]
#   ...
#   [158 156 162]
#   [158 156 162]
#   [158 156 162]]
#
#  [[165 163 169]
#   [165 163 169]
#   [165 163 169]
#   ...
#   [159 157 163]
#   [159 157 163]
#   [159 157 163]]
#
#  ...
#
#  [[ 80  84  78]
#   [ 78  82  77]
#   [ 78  82  76]
#   ...
#   [ 90  91  87]
#   [ 90  92  86]
#   [ 90  91  87]]
#
#  [[ 76  79  70]
#   [ 76  78  72]
#   [ 77  80  71]
#   ...
#   [ 90  92  86]
#   [ 89  92  83]
#   [ 88  90  84]]
#
#  [[ 75  78  69]
#   [ 75  78  69]
#   [ 74  77  68]
#   ...
#   [ 87  90  81]
#   [ 85  88  79]
#   [ 85  88  79]]]
# 0: 384x640 1 bottle, 159.3ms
# Speed: 5.2ms preprocess, 159.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 558
# [[[161 160 164]
#   [163 162 166]
#   [162 161 165]
#   ...
#   [154 153 155]
#   [154 153 155]
#   [153 152 154]]
#
#  [[161 160 164]
#   [162 161 165]
#   [160 159 163]
#   ...
#   [154 153 155]
#   [154 153 155]
#   [154 153 155]]
#
#  [[158 160 161]
#   [156 158 159]
#   [157 159 160]
#   ...
#   [153 152 154]
#   [153 152 154]
#   [154 153 155]]
#
#  ...
#
#  [[ 80  87  80]
#   [ 75  81  76]
#   [ 75  81  76]
#   ...
#   [ 92  92  92]
#   [ 92  92  92]
#   [ 92  92  92]]
#
#  [[ 79  86  79]
#   [ 75  82  75]
#   [ 74  81  74]
#   ...
#   [ 94  94  94]
#   [ 94  94  94]
#   [ 94  94  94]]
#
#  [[ 79  86  79]
#   [ 77  84  77]
#   [ 74  81  74]
#   ...
#   [ 96  96  96]
#   [ 95  95  95]
#   [ 95  95  95]]]
# 0: 384x640 1 bottle, 153.6ms
# Speed: 2.9ms preprocess, 153.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 563
# [[[ 57  65  95]
#   [ 56  64  94]
#   [ 56  64  94]
#   ...
#   [123 128 131]
#   [118 125 128]
#   [115 122 125]]
#
#  [[ 57  65  95]
#   [ 56  64  94]
#   [ 56  64  94]
#   ...
#   [123 128 131]
#   [119 126 129]
#   [116 123 126]]
#
#  [[ 57  65  95]
#   [ 56  64  94]
#   [ 56  64  94]
#   ...
#   [120 125 128]
#   [118 125 128]
#   [116 123 126]]
#
#  ...
#
#  [[ 77  80  78]
#   [ 78  81  79]
#   [ 78  81  79]
#   ...
#   [ 90  92  92]
#   [ 92  94  94]
#   [ 91  93  93]]
#
#  [[ 75  78  76]
#   [ 75  78  76]
#   [ 76  79  77]
#   ...
#   [ 90  92  92]
#   [ 90  92  92]
#   [ 90  92  92]]
#
#  [[ 73  76  74]
#   [ 74  78  73]
#   [ 74  77  75]
#   ...
#   [ 88  90  90]
#   [ 87  89  89]
#   [ 87  90  88]]]
# 0: 384x640 1 bottle, 160.0ms
# Speed: 2.4ms preprocess, 160.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 554
# [[[133 136 144]
#   [138 143 152]
#   [142 147 162]
#   ...
#   [114 120 127]
#   [117 120 128]
#   [117 120 128]]
#
#  [[146 148 156]
#   [145 146 156]
#   [147 148 162]
#   ...
#   [116 119 127]
#   [117 120 128]
#   [119 122 130]]
#
#  [[149 148 157]
#   [148 147 157]
#   [147 147 161]
#   ...
#   [117 120 128]
#   [117 120 128]
#   [119 122 130]]
#
#  ...
#
#  [[ 77  82  80]
#   [ 76  81  79]
#   [ 78  81  79]
#   ...
#   [ 88  88  88]
#   [ 88  88  88]
#   [ 87  87  87]]
#
#  [[ 77  82  80]
#   [ 76  81  79]
#   [ 78  81  79]
#   ...
#   [ 86  86  86]
#   [ 88  88  88]
#   [ 88  88  88]]
#
#  [[ 80  84  79]
#   [ 74  78  73]
#   [ 77  80  78]
#   ...
#   [ 86  86  86]
#   [ 88  88  88]
#   [ 89  89  89]]]
# 0: 384x640 (no detections), 156.6ms
# Speed: 2.5ms preprocess, 156.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 134.5ms
# Speed: 2.8ms preprocess, 134.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 346
# [[[ 43  42  46]
#   [ 43  42  46]
#   [ 42  41  45]
#   ...
#   [186 167 170]
#   [186 167 170]
#   [188 167 170]]
#
#  [[ 41  40  44]
#   [ 41  40  44]
#   [ 41  40  44]
#   ...
#   [186 167 170]
#   [185 166 169]
#   [185 164 167]]
#
#  [[ 41  40  44]
#   [ 41  40  44]
#   [ 41  40  44]
#   ...
#   [186 167 170]
#   [184 165 168]
#   [182 161 164]]
#
#  ...
#
#  [[120 120 126]
#   [121 121 127]
#   [121 121 127]
#   ...
#   [130 129 133]
#   [130 129 133]
#   [130 128 134]]
#
#  [[122 122 128]
#   [122 122 128]
#   [123 123 129]
#   ...
#   [130 128 134]
#   [130 128 134]
#   [130 128 134]]
#
#  [[124 124 130]
#   [124 124 130]
#   [124 124 130]
#   ...
#   [129 127 133]
#   [129 127 133]
#   [131 129 135]]]
# 0: 384x640 (no detections), 175.7ms
# Speed: 2.7ms preprocess, 175.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 134.4ms
# Speed: 2.5ms preprocess, 134.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 150.7ms
# Speed: 3.8ms preprocess, 150.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 319
# [[[154 152 158]
#   [155 153 159]
#   [155 153 159]
#   ...
#   [151 150 152]
#   [151 150 152]
#   [150 149 151]]
#
#  [[155 153 159]
#   [155 153 159]
#   [156 154 160]
#   ...
#   [151 150 152]
#   [151 150 152]
#   [151 150 152]]
#
#  [[155 153 159]
#   [155 153 159]
#   [155 153 159]
#   ...
#   [148 147 149]
#   [148 147 149]
#   [148 147 149]]
#
#  ...
#
#  [[ 92  94 102]
#   [ 90  92 100]
#   [ 88  90  98]
#   ...
#   [ 39  47  47]
#   [ 39  47  47]
#   [ 42  47  48]]
#
#  [[ 92  94 102]
#   [ 91  93 101]
#   [ 90  92 100]
#   ...
#   [ 39  47  47]
#   [ 39  47  47]
#   [ 43  48  49]]
#
#  [[ 93  95 103]
#   [ 90  92 100]
#   [ 88  90  98]
#   ...
#   [ 44  50  49]
#   [ 45  51  50]
#   [ 46  52  51]]]
# 0: 384x640 1 bottle, 135.8ms
# Speed: 2.8ms preprocess, 135.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 282
# [[[108 111 119]
#   [108 111 119]
#   [107 110 118]
#   ...
#   [ 84  89  98]
#   [ 83  88  97]
#   [ 83  89  96]]
#
#  [[106 109 117]
#   [106 109 117]
#   [105 108 116]
#   ...
#   [ 84  89  98]
#   [ 84  89  98]
#   [ 84  90  97]]
#
#  [[106 109 117]
#   [106 109 117]
#   [105 108 116]
#   ...
#   [ 87  89  99]
#   [ 87  90  98]
#   [ 87  90  98]]
#
#  ...
#
#  [[ 79  81  82]
#   [ 79  81  82]
#   [ 79  81  82]
#   ...
#   [ 33  38  39]
#   [ 34  39  40]
#   [ 34  39  40]]
#
#  [[ 82  81  83]
#   [ 83  82  84]
#   [ 83  82  84]
#   ...
#   [ 35  40  39]
#   [ 36  41  40]
#   [ 36  41  40]]
#
#  [[ 79  78  80]
#   [ 82  81  83]
#   [ 82  81  83]
#   ...
#   [ 38  43  42]
#   [ 39  44  43]
#   [ 39  44  43]]]
# 0: 384x640 1 bottle, 146.7ms
# Speed: 3.3ms preprocess, 146.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 406
# [[[148 148 148]
#   [147 147 147]
#   [146 146 146]
#   ...
#   [135 135 135]
#   [136 136 136]
#   [138 138 138]]
#
#  [[148 148 148]
#   [148 148 148]
#   [148 148 148]
#   ...
#   [135 135 135]
#   [136 136 136]
#   [139 139 139]]
#
#  [[148 148 148]
#   [148 148 148]
#   [148 148 148]
#   ...
#   [134 134 134]
#   [135 135 135]
#   [138 138 138]]
#
#  ...
#
#  [[137 139 147]
#   [139 141 149]
#   [139 141 149]
#   ...
#   [134 138 139]
#   [134 138 139]
#   [134 138 139]]
#
#  [[138 140 148]
#   [140 142 150]
#   [139 141 149]
#   ...
#   [134 138 139]
#   [134 138 139]
#   [134 138 139]]
#
#  [[140 142 150]
#   [140 142 150]
#   [139 141 149]
#   ...
#   [134 138 139]
#   [134 138 139]
#   [134 138 139]]]
# 0: 384x640 (no detections), 166.8ms
# Speed: 3.1ms preprocess, 166.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 145.7ms
# Speed: 2.5ms preprocess, 145.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 331
# [[[153 151 157]
#   [154 152 158]
#   [155 153 159]
#   ...
#   [144 143 147]
#   [142 141 145]
#   [145 144 148]]
#
#  [[155 153 159]
#   [156 154 160]
#   [156 154 160]
#   ...
#   [145 144 148]
#   [144 143 147]
#   [144 143 147]]
#
#  [[157 155 161]
#   [157 155 161]
#   [157 155 161]
#   ...
#   [145 144 146]
#   [144 143 145]
#   [144 143 145]]
#
#  ...
#
#  [[100  99 101]
#   [103 102 104]
#   [100  99 101]
#   ...
#   [ 39  44  45]
#   [ 41  46  47]
#   [ 45  50  51]]
#
#  [[101 100 102]
#   [104 103 105]
#   [101 100 102]
#   ...
#   [ 43  48  49]
#   [ 45  50  51]
#   [ 46  51  52]]
#
#  [[101 100 102]
#   [104 103 105]
#   [102 101 103]
#   ...
#   [ 48  53  54]
#   [ 48  53  54]
#   [ 47  51  52]]]
# 0: 384x640 1 bottle, 169.8ms
# Speed: 4.9ms preprocess, 169.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# 329
# [[[153 152 156]
#   [153 152 156]
#   [152 151 155]
#   ...
#   [147 146 148]
#   [147 146 148]
#   [144 143 145]]
#
#  [[154 153 157]
#   [154 153 157]
#   [154 153 157]
#   ...
#   [147 146 148]
#   [147 146 148]
#   [147 146 148]]
#
#  [[156 155 159]
#   [156 155 159]
#   [156 155 159]
#   ...
#   [146 145 147]
#   [146 145 147]
#   [148 147 149]]
#
#  ...
#
#  [[100  99 101]
#   [100  99 101]
#   [ 99  99  99]
#   ...
#   [ 38  46  46]
#   [ 39  47  47]
#   [ 41  49  49]]
#
#  [[100  99 101]
#   [102 101 103]
#   [100 100 100]
#   ...
#   [ 39  47  47]
#   [ 40  48  48]
#   [ 41  49  49]]
#
#  [[100  99 101]
#   [101 100 102]
#   [100  99 101]
#   ...
#   [ 40  48  48]
#   [ 41  49  49]
#   [ 42  50  50]]]
# 0: 384x640 (no detections), 204.8ms
# Speed: 3.8ms preprocess, 204.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bottle, 143.0ms
# Speed: 2.4ms preprocess, 143.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 407
# [[[147 147 147]
#   [147 147 147]
#   [147 147 147]
#   ...
#   [137 137 137]
#   [137 137 137]
#   [136 136 136]]
#
#  [[146 146 146]
#   [146 146 146]
#   [147 147 147]
#   ...
#   [136 136 136]
#   [136 136 136]
#   [136 136 136]]
#
#  [[146 146 146]
#   [146 146 146]
#   [146 146 146]
#   ...
#   [136 136 136]
#   [136 136 136]
#   [136 136 136]]
#
#  ...
#
#  [[142 144 152]
#   [141 143 151]
#   [139 141 149]
#   ...
#   [134 138 139]
#   [134 138 139]
#   [135 138 142]]
#
#  [[142 144 152]
#   [141 143 151]
#   [140 142 150]
#   ...
#   [134 138 139]
#   [134 138 139]
#   [135 138 142]]
#
#  [[142 144 152]
#   [141 143 151]
#   [140 142 150]
#   ...
#   [134 138 139]
#   [134 138 139]
#   [135 138 142]]]
# 0: 384x640 1 bottle, 129.3ms
# Speed: 2.6ms preprocess, 129.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 301
# [[[160 157 166]
#   [159 156 165]
#   [158 155 164]
#   ...
#   [148 146 152]
#   [149 147 153]
#   [151 149 155]]
#
#  [[159 157 163]
#   [159 157 163]
#   [159 157 163]
#   ...
#   [151 149 155]
#   [152 150 156]
#   [150 148 154]]
#
#  [[157 155 161]
#   [157 155 161]
#   [157 155 161]
#   ...
#   [148 146 152]
#   [149 147 153]
#   [149 147 153]]
#
#  ...
#
#  [[ 78  80  81]
#   [ 80  82  83]
#   [ 85  84  86]
#   ...
#   [ 37  45  45]
#   [ 37  45  45]
#   [ 38  46  46]]
#
#  [[ 78  80  81]
#   [ 80  82  83]
#   [ 85  84  86]
#   ...
#   [ 39  47  47]
#   [ 39  47  47]
#   [ 40  48  48]]
#
#  [[ 79  81  82]
#   [ 80  82  83]
#   [ 85  84  86]
#   ...
#   [ 41  49  49]
#   [ 41  49  49]
#   [ 42  50  50]]]
# 0: 384x640 1 bottle, 158.0ms
# Speed: 2.6ms preprocess, 158.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 357
# [[[178 176 182]
#   [179 177 183]
#   [179 177 183]
#   ...
#   [167 166 176]
#   [167 166 176]
#   [167 166 176]]
#
#  [[180 178 184]
#   [180 178 184]
#   [179 177 183]
#   ...
#   [165 164 174]
#   [166 165 175]
#   [165 164 174]]
#
#  [[179 177 183]
#   [178 176 182]
#   [177 175 181]
#   ...
#   [164 163 173]
#   [164 163 173]
#   [164 163 173]]
#
#  ...
#
#  [[109 113 118]
#   [111 115 120]
#   [115 119 124]
#   ...
#   [112 114 122]
#   [111 113 121]
#   [109 112 120]]
#
#  [[112 115 120]
#   [114 116 124]
#   [116 118 126]
#   ...
#   [108 112 117]
#   [109 113 118]
#   [111 114 122]]
#
#  [[113 116 121]
#   [114 116 124]
#   [115 117 125]
#   ...
#   [109 113 118]
#   [109 113 118]
#   [111 114 122]]]
# 0: 384x640 1 bottle, 160.1ms
# Speed: 2.4ms preprocess, 160.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 697
# [[[137 137 137]
#   [137 137 137]
#   [137 137 137]
#   ...
#   [107 108 112]
#   [106 107 111]
#   [109 108 110]]
#
#  [[136 135 137]
#   [136 135 137]
#   [136 136 136]
#   ...
#   [105 106 110]
#   [105 106 110]
#   [106 107 111]]
#
#  [[136 135 137]
#   [136 135 137]
#   [136 136 136]
#   ...
#   [104 105 109]
#   [104 105 109]
#   [102 105 109]]
#
#  ...
#
#  [[ 52  60  59]
#   [ 53  61  60]
#   [ 54  62  61]
#   ...
#   [ 40  47  50]
#   [ 40  47  50]
#   [ 40  47  50]]
#
#  [[ 56  62  61]
#   [ 57  63  62]
#   [ 58  64  63]
#   ...
#   [ 40  47  50]
#   [ 40  47  50]
#   [ 40  47  50]]
#
#  [[ 58  64  63]
#   [ 58  64  63]
#   [ 59  64  65]
#   ...
#   [ 41  48  51]
#   [ 41  48  51]
#   [ 41  48  51]]]
# 0: 384x640 1 bottle, 164.3ms
# Speed: 3.1ms preprocess, 164.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 673
# [[[117 118 122]
#   [117 118 122]
#   [117 118 122]
#   ...
#   [ 78  82  83]
#   [ 78  83  86]
#   [ 78  83  86]]
#
#  [[117 118 122]
#   [117 118 122]
#   [117 118 122]
#   ...
#   [ 78  81  85]
#   [ 78  83  86]
#   [ 78  83  86]]
#
#  [[117 118 122]
#   [117 118 122]
#   [117 118 122]
#   ...
#   [ 79  82  86]
#   [ 78  83  86]
#   [ 78  83  86]]
#
#  ...
#
#  [[ 42  51  55]
#   [ 42  51  55]
#   [ 39  49  56]
#   ...
#   [ 30  32  33]
#   [ 29  33  34]
#   [ 31  35  36]]
#
#  [[ 42  51  55]
#   [ 42  51  55]
#   [ 39  49  56]
#   ...
#   [ 28  30  30]
#   [ 27  32  31]
#   [ 28  33  32]]
#
#  [[ 42  51  55]
#   [ 42  51  55]
#   [ 39  49  56]
#   ...
#   [ 25  30  28]
#   [ 24  29  27]
#   [ 23  30  27]]]
# 0: 384x640 1 bottle, 155.0ms
# Speed: 2.0ms preprocess, 155.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 296
# [[[ 42  42  48]
#   [ 67  67  73]
#   [112 112 118]
#   ...
#   [109 113 132]
#   [115 118 132]
#   [118 119 129]]
#
#  [[ 41  41  47]
#   [ 66  66  72]
#   [112 112 118]
#   ...
#   [114 117 132]
#   [120 122 133]
#   [122 124 132]]
#
#  [[ 40  40  46]
#   [ 65  65  71]
#   [112 112 118]
#   ...
#   [113 114 128]
#   [117 119 129]
#   [120 123 128]]
#
#  ...
#
#  [[114 109 118]
#   [114 109 118]
#   [115 110 119]
#   ...
#   [117 116 125]
#   [119 118 127]
#   [120 119 128]]
#
#  [[115 110 119]
#   [115 110 119]
#   [115 110 119]
#   ...
#   [118 117 126]
#   [119 118 127]
#   [120 119 128]]
#
#  [[115 110 119]
#   [115 110 119]
#   [115 110 119]
#   ...
#   [118 117 126]
#   [120 119 128]
#   [120 119 128]]]
# 0: 384x640 1 bottle, 201.8ms
# Speed: 5.9ms preprocess, 201.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 327
# [[[ 42  46  47]
#   [ 43  47  48]
#   [ 43  47  48]
#   ...
#   [ 83  78  79]
#   [ 81  79  79]
#   [ 80  78  78]]
#
#  [[ 42  46  47]
#   [ 43  47  48]
#   [ 43  47  48]
#   ...
#   [ 83  78  79]
#   [ 81  79  79]
#   [ 80  78  78]]
#
#  [[ 43  47  48]
#   [ 44  48  49]
#   [ 44  48  49]
#   ...
#   [ 83  81  81]
#   [ 83  81  81]
#   [ 81  79  79]]
#
#  ...
#
#  [[152 156 167]
#   [151 157 168]
#   [152 158 169]
#   ...
#   [152 159 168]
#   [153 160 169]
#   [152 159 168]]
#
#  [[153 157 168]
#   [153 159 170]
#   [154 160 171]
#   ...
#   [156 163 172]
#   [153 160 169]
#   [152 159 168]]
#
#  [[153 157 168]
#   [156 160 171]
#   [157 161 172]
#   ...
#   [154 161 170]
#   [154 162 169]
#   [153 161 168]]]
# 0: 384x640 1 bottle, 165.8ms
# Speed: 2.4ms preprocess, 165.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 566
# [[[ 68  76  99]
#   [ 63  74  96]
#   [ 69  81 105]
#   ...
#   [122 125 129]
#   [122 125 129]
#   [122 126 127]]
#
#  [[ 76  83 103]
#   [ 62  70  93]
#   [ 61  71  95]
#   ...
#   [122 125 129]
#   [121 125 126]
#   [121 125 126]]
#
#  [[110 116 135]
#   [ 80  87 107]
#   [ 63  71  94]
#   ...
#   [121 125 126]
#   [120 124 125]
#   [120 124 125]]
#
#  ...
#
#  [[ 73  76  67]
#   [ 74  77  68]
#   [ 74  77  68]
#   ...
#   [ 77  81  76]
#   [ 77  81  76]
#   [ 78  80  74]]
#
#  [[ 71  74  65]
#   [ 72  75  66]
#   [ 72  75  66]
#   ...
#   [ 76  80  75]
#   [ 79  81  75]
#   [ 80  81  72]]
#
#  [[ 71  75  64]
#   [ 71  75  64]
#   [ 71  75  64]
#   ...
#   [ 78  80  74]
#   [ 78  80  74]
#   [ 79  80  71]]]
# 0: 384x640 1 bottle, 184.9ms
# Speed: 16.7ms preprocess, 184.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 562
# [[[166 165 169]
#   [166 164 170]
#   [165 164 168]
#   ...
#   [159 157 163]
#   [158 156 162]
#   [158 156 162]]
#
#  [[167 165 171]
#   [166 163 172]
#   [165 163 169]
#   ...
#   [158 157 161]
#   [158 157 161]
#   [158 157 161]]
#
#  [[167 164 173]
#   [166 163 172]
#   [166 163 172]
#   ...
#   [158 157 161]
#   [158 157 161]
#   [158 157 161]]
#
#  ...
#
#  [[ 80  84  78]
#   [ 82  86  80]
#   [ 85  89  83]
#   ...
#   [ 86  91  82]
#   [ 88  93  84]
#   [ 91  96  87]]
#
#  [[ 80  84  78]
#   [ 83  87  81]
#   [ 86  90  84]
#   ...
#   [ 86  90  84]
#   [ 87  92  83]
#   [ 88  92  86]]
#
#  [[ 79  80  76]
#   [ 79  80  76]
#   [ 80  81  77]
#   ...
#   [ 88  89  85]
#   [ 87  89  83]
#   [ 87  88  84]]]
# 0: 384x640 1 bottle, 150.5ms
# Speed: 2.5ms preprocess, 150.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 558
# [[[156 155 159]
#   [155 154 158]
#   [155 154 158]
#   ...
#   [152 151 153]
#   [152 151 153]
#   [151 150 152]]
#
#  [[156 155 159]
#   [155 154 158]
#   [155 154 158]
#   ...
#   [151 150 152]
#   [151 150 152]
#   [152 151 153]]
#
#  [[157 155 161]
#   [156 154 160]
#   [156 154 160]
#   ...
#   [151 151 151]
#   [151 151 151]
#   [152 152 152]]
#
#  ...
#
#  [[ 73  80  75]
#   [ 74  81  76]
#   [ 74  81  76]
#   ...
#   [ 91  92  88]
#   [ 90  91  87]
#   [ 91  92  88]]
#
#  [[ 76  83  78]
#   [ 76  83  78]
#   [ 75  82  77]
#   ...
#   [ 93  94  90]
#   [ 91  92  88]
#   [ 91  92  88]]
#
#  [[ 77  84  79]
#   [ 77  84  79]
#   [ 76  83  78]
#   ...
#   [ 95  96  92]
#   [ 93  94  90]
#   [ 92  93  89]]]
